# %%
from __future__ import division
from __future__ import print_function
import requests
import json
import urllib
import math
import pandas as pd
import numpy as np
import random
import datetime

# %% [markdown]
# # Generates Data to prepare for API calls

# %%
def prepare_addresses(address):
    return address.replace(" ", "+")

# %%
random.seed(10)

data_path = 'C:/Users/User/Desktop/Math402w/Math402W Proj/winnipeg_test_2/4420addresses.xlsx'
data = pd.read_excel(data_path, skiprows = 2)


# prepares the data for API calls
columns_to_prepare = ['Street Number', 'Street Name', 'City', 'Province']

for column in columns_to_prepare:
    data[column] = data[column].astype(str).apply(prepare_addresses)


for i in range(0, len(columns_to_prepare)):
    
    if i == 0:
        address_transformed = data[columns_to_prepare[i]] + '+'
    elif i != len(columns_to_prepare) - 1:
        address_transformed = address_transformed + data[columns_to_prepare[i]]  + '+'
    else:
        address_transformed = address_transformed +  data[columns_to_prepare[i]]

address_transformed = address_transformed.to_list()

#API calls can take a maximum of 25 locations - more needs to be paid
address_prepared = [address_transformed[0]]
address_transformed.pop(0)

address_prepared = address_prepared + random.sample(address_transformed, 21)
address_prepared
# Out:
# ['1555+Regent+Ave+W+Winnipeg+MB',
#  '272+Poplarwood+Ave+Winnipeg+MB',
#  '378+Jacques+Ave+Winnipeg+MB',
#  '532+Cherrier+St+Winnipeg+MB',
#  '95+Fallbrook+Bay+Winnipeg+MB',
#  '63+Regal+Ave+Winnipeg+MB',
#  '1320+Concordia+Ave+E+Winnipeg+MB',
#  '11+Rizzuto+Bay+Winnipeg+MB',
#  '876+Elizabeth+Rd+Winnipeg+MB',
#  '135+Driftwood+Bay+Winnipeg+MB',
#  '9+Kootenay+Crescent+Winnipeg+MB',
#  '1575+Lagimodiere+Blvd+Winnipeg+MB',
#  '47+Eric+St+Winnipeg+MB',
#  '45+Willowlake+Crescent+Winnipeg+MB',
#  "515+St+Anne's+Rd+Winnipeg+MB",
#  '209+Yale+Ave+W+Winnipeg+MB',
#  '150+Howden+Rd+Winnipeg+MB',
#  '75+Golis+Bay+Winnipeg+MB',
#  '975+Cottonwood+Rd+Winnipeg+MB',
#  '556+Brewster+St+Winnipeg+MB',
#  '72+Rutledge+Crescent+Winnipeg+MB',
#  '29+Des+Meurons+St+Winnipeg+MB']

# %% [markdown]
# # Config + Helper Functions

# %%
def create_data():
  """Creates the data."""
  data = {}
  data['API_key'] = 'AIzaSyD3ugHNzB5HxwLD-Z2tW9QQTd-lm4shI-w'
  data['delivery_start_time'] = '7AM'
  data['delivery_end_time'] = '2PM' 
  data['addresses'] = address_prepared
  return data

def create_distance_matrix(data):
  addresses = data["addresses"]
  API_key = data["API_key"] 
  # Distance Matrix API only accepts 100 elements per request, so get rows in multiple requests.
  max_elements = 100
  num_addresses = len(addresses)
  # Maximum number of rows that can be computed per request (6 in this example).
  max_rows = max_elements // num_addresses
  # num_addresses = q * max_rows + r (q = 2 and r = 4 in this example).
  q, r = divmod(num_addresses, max_rows)
  dest_addresses = addresses
  distance_matrix = []
  # Send q requests, returning max_rows rows per request.
  for i in range(q):
    origin_addresses = addresses[i * max_rows: (i + 1) * max_rows]
    response = send_request(origin_addresses, dest_addresses, API_key)
    print(response['status']) #USE THIS TO DEBUG
    distance_matrix += build_distance_matrix(response)

  # Get the remaining remaining r rows, if necessary.
  if r > 0:
    origin_addresses = addresses[q * max_rows: q * max_rows + r]
    response = send_request(origin_addresses, dest_addresses, API_key)
    distance_matrix += build_distance_matrix(response)
  return distance_matrix

def send_request(origin_addresses, dest_addresses, API_key):
  """ Build and send request for the given origin and destination addresses."""
  def build_address_str(addresses):
    # Build a pipe-separated string of addresses
    address_str = ''
    for i in range(len(addresses) - 1):
      address_str += addresses[i] + '|'
    address_str += addresses[-1]
    return address_str

  request = 'https://maps.googleapis.com/maps/api/distancematrix/json?units=metric'
  origin_address_str = build_address_str(origin_addresses)
  dest_address_str = build_address_str(dest_addresses)
  request = request + '&origins=' + origin_address_str + '&destinations=' + \
                       dest_address_str + '&key=' + API_key
  jsonResult = urllib.request.urlopen(request).read()
  response = json.loads(jsonResult)
  return response

def build_distance_matrix(response):
  distance_matrix = []
  for row in response['rows']:
    row_list = [math.ceil(row['elements'][j]['duration']['value']/60) for j in range(len(row['elements']))]
    distance_matrix.append(row_list)
  return distance_matrix

# %% [markdown]
# # Performs API Calls

# %%
data = create_data()
addresses = data['addresses']
API_key = data['API_key']
distance_matrix = create_distance_matrix(data)
# Out:
# OK
# OK
# REQUEST_DENIED
# OK
# OK

# %% [markdown]
# # Process API Calls output

# %%
processed_data = pd.DataFrame(distance_matrix, columns = address_prepared)
processed_data.index = address_prepared
processed_data
# Out:
#                                     1555+Regent+Ave+W+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                   0
# 272+Poplarwood+Ave+Winnipeg+MB                                 17
# 378+Jacques+Ave+Winnipeg+MB                                     8
# 532+Cherrier+St+Winnipeg+MB                                    11
# 95+Fallbrook+Bay+Winnipeg+MB                                   15
# 63+Regal+Ave+Winnipeg+MB                                       17
# 1320+Concordia+Ave+E+Winnipeg+MB                                6
# 11+Rizzuto+Bay+Winnipeg+MB                                      4
# 876+Elizabeth+Rd+Winnipeg+MB                                    9
# 135+Driftwood+Bay+Winnipeg+MB                                  14
# 9+Kootenay+Crescent+Winnipeg+MB                                 8
# 1575+Lagimodiere+Blvd+Winnipeg+MB                               5
# 47+Eric+St+Winnipeg+MB                                         19
# 45+Willowlake+Crescent+Winnipeg+MB                             15
# 515+St+Anne's+Rd+Winnipeg+MB                                   17
# 209+Yale+Ave+W+Winnipeg+MB                                      8
# 150+Howden+Rd+Winnipeg+MB                                      11
# 75+Golis+Bay+Winnipeg+MB                                        8
# 975+Cottonwood+Rd+Winnipeg+MB                                  11
# 556+Brewster+St+Winnipeg+MB                                     7
# 72+Rutledge+Crescent+Winnipeg+MB                                9
# 29+Des+Meurons+St+Winnipeg+MB                                  14
#
#                                     272+Poplarwood+Ave+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                   17
# 272+Poplarwood+Ave+Winnipeg+MB                                   0
# 378+Jacques+Ave+Winnipeg+MB                                     19
# 532+Cherrier+St+Winnipeg+MB                                     10
# 95+Fallbrook+Bay+Winnipeg+MB                                     7
# 63+Regal+Ave+Winnipeg+MB                                         5
# 1320+Concordia+Ave+E+Winnipeg+MB                                17
# 11+Rizzuto+Bay+Winnipeg+MB                                      17
# 876+Elizabeth+Rd+Winnipeg+MB                                     8
# 135+Driftwood+Bay+Winnipeg+MB                                    6
# 9+Kootenay+Crescent+Winnipeg+MB                                 20
# 1575+Lagimodiere+Blvd+Winnipeg+MB                               16
# 47+Eric+St+Winnipeg+MB                                           5
# 45+Willowlake+Crescent+Winnipeg+MB                               6
# 515+St+Anne's+Rd+Winnipeg+MB                                     2
# 209+Yale+Ave+W+Winnipeg+MB                                      20
# 150+Howden+Rd+Winnipeg+MB                                        9
# 75+Golis+Bay+Winnipeg+MB                                        20
# 975+Cottonwood+Rd+Winnipeg+MB                                    7
# 556+Brewster+St+Winnipeg+MB                                     18
# 72+Rutledge+Crescent+Winnipeg+MB                                20
# 29+Des+Meurons+St+Winnipeg+MB                                    8
#
#                                     378+Jacques+Ave+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                 7
# 272+Poplarwood+Ave+Winnipeg+MB                               19
# 378+Jacques+Ave+Winnipeg+MB                                   0
# 532+Cherrier+St+Winnipeg+MB                                  13
# 95+Fallbrook+Bay+Winnipeg+MB                                 18
# 63+Regal+Ave+Winnipeg+MB                                     19
# 1320+Concordia+Ave+E+Winnipeg+MB                              4
# 11+Rizzuto+Bay+Winnipeg+MB                                    9
# 876+Elizabeth+Rd+Winnipeg+MB                                 12
# 135+Driftwood+Bay+Winnipeg+MB                                17
# 9+Kootenay+Crescent+Winnipeg+MB                               7
# 1575+Lagimodiere+Blvd+Winnipeg+MB                             6
# 47+Eric+St+Winnipeg+MB                                       22
# 45+Willowlake+Crescent+Winnipeg+MB                           17
# 515+St+Anne's+Rd+Winnipeg+MB                                 20
# 209+Yale+Ave+W+Winnipeg+MB                                   10
# 150+Howden+Rd+Winnipeg+MB                                    13
# 75+Golis+Bay+Winnipeg+MB                                      4
# 975+Cottonwood+Rd+Winnipeg+MB                                13
# 556+Brewster+St+Winnipeg+MB                                   7
# 72+Rutledge+Crescent+Winnipeg+MB                              3
# 29+Des+Meurons+St+Winnipeg+MB                                16
#
#                                     532+Cherrier+St+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                11
# 272+Poplarwood+Ave+Winnipeg+MB                               10
# 378+Jacques+Ave+Winnipeg+MB                                  13
# 532+Cherrier+St+Winnipeg+MB                                   0
# 95+Fallbrook+Bay+Winnipeg+MB                                  9
# 63+Regal+Ave+Winnipeg+MB                                      9
# 1320+Concordia+Ave+E+Winnipeg+MB                             11
# 11+Rizzuto+Bay+Winnipeg+MB                                   11
# 876+Elizabeth+Rd+Winnipeg+MB                                  6
# 135+Driftwood+Bay+Winnipeg+MB                                12
# 9+Kootenay+Crescent+Winnipeg+MB                              14
# 1575+Lagimodiere+Blvd+Winnipeg+MB                            10
# 47+Eric+St+Winnipeg+MB                                       13
# 45+Willowlake+Crescent+Winnipeg+MB                            9
# 515+St+Anne's+Rd+Winnipeg+MB                                 11
# 209+Yale+Ave+W+Winnipeg+MB                                   15
# 150+Howden+Rd+Winnipeg+MB                                     8
# 75+Golis+Bay+Winnipeg+MB                                     14
# 975+Cottonwood+Rd+Winnipeg+MB                                 7
# 556+Brewster+St+Winnipeg+MB                                  13
# 72+Rutledge+Crescent+Winnipeg+MB                             14
# 29+Des+Meurons+St+Winnipeg+MB                                 6
#
#                                     95+Fallbrook+Bay+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                 15
# 272+Poplarwood+Ave+Winnipeg+MB                                 6
# 378+Jacques+Ave+Winnipeg+MB                                   17
# 532+Cherrier+St+Winnipeg+MB                                    9
# 95+Fallbrook+Bay+Winnipeg+MB                                   0
# 63+Regal+Ave+Winnipeg+MB                                       6
# 1320+Concordia+Ave+E+Winnipeg+MB                              16
# 11+Rizzuto+Bay+Winnipeg+MB                                    15
# 876+Elizabeth+Rd+Winnipeg+MB                                   7
# 135+Driftwood+Bay+Winnipeg+MB                                  5
# 9+Kootenay+Crescent+Winnipeg+MB                               18
# 1575+Lagimodiere+Blvd+Winnipeg+MB                             15
# 47+Eric+St+Winnipeg+MB                                        10
# 45+Willowlake+Crescent+Winnipeg+MB                             2
# 515+St+Anne's+Rd+Winnipeg+MB                                   7
# 209+Yale+Ave+W+Winnipeg+MB                                    18
# 150+Howden+Rd+Winnipeg+MB                                      7
# 75+Golis+Bay+Winnipeg+MB                                      18
# 975+Cottonwood+Rd+Winnipeg+MB                                  5
# 556+Brewster+St+Winnipeg+MB                                   17
# 72+Rutledge+Crescent+Winnipeg+MB                              19
# 29+Des+Meurons+St+Winnipeg+MB                                  9
#
#                                     63+Regal+Ave+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                             16
# 272+Poplarwood+Ave+Winnipeg+MB                             5
# 378+Jacques+Ave+Winnipeg+MB                               19
# 532+Cherrier+St+Winnipeg+MB                                9
# 95+Fallbrook+Bay+Winnipeg+MB                               7
# 63+Regal+Ave+Winnipeg+MB                                   0
# 1320+Concordia+Ave+E+Winnipeg+MB                          17
# 11+Rizzuto+Bay+Winnipeg+MB                                17
# 876+Elizabeth+Rd+Winnipeg+MB                               8
# 135+Driftwood+Bay+Winnipeg+MB                             10
# 9+Kootenay+Crescent+Winnipeg+MB                           19
# 1575+Lagimodiere+Blvd+Winnipeg+MB                         16
# 47+Eric+St+Winnipeg+MB                                     7
# 45+Willowlake+Crescent+Winnipeg+MB                         7
# 515+St+Anne's+Rd+Winnipeg+MB                               5
# 209+Yale+Ave+W+Winnipeg+MB                                19
# 150+Howden+Rd+Winnipeg+MB                                  8
# 75+Golis+Bay+Winnipeg+MB                                  19
# 975+Cottonwood+Rd+Winnipeg+MB                              6
# 556+Brewster+St+Winnipeg+MB                               18
# 72+Rutledge+Crescent+Winnipeg+MB                          20
# 29+Des+Meurons+St+Winnipeg+MB                              6
#
#                                     1320+Concordia+Ave+E+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                      5
# 272+Poplarwood+Ave+Winnipeg+MB                                    17
# 378+Jacques+Ave+Winnipeg+MB                                        5
# 532+Cherrier+St+Winnipeg+MB                                       11
# 95+Fallbrook+Bay+Winnipeg+MB                                      16
# 63+Regal+Ave+Winnipeg+MB                                          17
# 1320+Concordia+Ave+E+Winnipeg+MB                                   0
# 11+Rizzuto+Bay+Winnipeg+MB                                         7
# 876+Elizabeth+Rd+Winnipeg+MB                                      10
# 135+Driftwood+Bay+Winnipeg+MB                                     15
# 9+Kootenay+Crescent+Winnipeg+MB                                    7
# 1575+Lagimodiere+Blvd+Winnipeg+MB                                  4
# 47+Eric+St+Winnipeg+MB                                            20
# 45+Willowlake+Crescent+Winnipeg+MB                                15
# 515+St+Anne's+Rd+Winnipeg+MB                                      18
# 209+Yale+Ave+W+Winnipeg+MB                                         9
# 150+Howden+Rd+Winnipeg+MB                                         11
# 75+Golis+Bay+Winnipeg+MB                                           3
# 975+Cottonwood+Rd+Winnipeg+MB                                     11
# 556+Brewster+St+Winnipeg+MB                                        6
# 72+Rutledge+Crescent+Winnipeg+MB                                   4
# 29+Des+Meurons+St+Winnipeg+MB                                     14
#
#                                     11+Rizzuto+Bay+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                5
# 272+Poplarwood+Ave+Winnipeg+MB                              18
# 378+Jacques+Ave+Winnipeg+MB                                 10
# 532+Cherrier+St+Winnipeg+MB                                 12
# 95+Fallbrook+Bay+Winnipeg+MB                                16
# 63+Regal+Ave+Winnipeg+MB                                    18
# 1320+Concordia+Ave+E+Winnipeg+MB                             7
# 11+Rizzuto+Bay+Winnipeg+MB                                   0
# 876+Elizabeth+Rd+Winnipeg+MB                                10
# 135+Driftwood+Bay+Winnipeg+MB                               15
# 9+Kootenay+Crescent+Winnipeg+MB                              8
# 1575+Lagimodiere+Blvd+Winnipeg+MB                            8
# 47+Eric+St+Winnipeg+MB                                      20
# 45+Willowlake+Crescent+Winnipeg+MB                          16
# 515+St+Anne's+Rd+Winnipeg+MB                                18
# 209+Yale+Ave+W+Winnipeg+MB                                   8
# 150+Howden+Rd+Winnipeg+MB                                   12
# 75+Golis+Bay+Winnipeg+MB                                     9
# 975+Cottonwood+Rd+Winnipeg+MB                               12
# 556+Brewster+St+Winnipeg+MB                                  7
# 72+Rutledge+Crescent+Winnipeg+MB                            10
# 29+Des+Meurons+St+Winnipeg+MB                               15
#
#                                     876+Elizabeth+Rd+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                  9
# 272+Poplarwood+Ave+Winnipeg+MB                                 8
# 378+Jacques+Ave+Winnipeg+MB                                   12
# 532+Cherrier+St+Winnipeg+MB                                    6
# 95+Fallbrook+Bay+Winnipeg+MB                                   7
# 63+Regal+Ave+Winnipeg+MB                                       9
# 1320+Concordia+Ave+E+Winnipeg+MB                              10
# 11+Rizzuto+Bay+Winnipeg+MB                                    10
# 876+Elizabeth+Rd+Winnipeg+MB                                   0
# 135+Driftwood+Bay+Winnipeg+MB                                  9
# 9+Kootenay+Crescent+Winnipeg+MB                               13
# 1575+Lagimodiere+Blvd+Winnipeg+MB                              9
# 47+Eric+St+Winnipeg+MB                                        12
# 45+Willowlake+Crescent+Winnipeg+MB                             7
# 515+St+Anne's+Rd+Winnipeg+MB                                   9
# 209+Yale+Ave+W+Winnipeg+MB                                    13
# 150+Howden+Rd+Winnipeg+MB                                      3
# 75+Golis+Bay+Winnipeg+MB                                      12
# 975+Cottonwood+Rd+Winnipeg+MB                                  3
# 556+Brewster+St+Winnipeg+MB                                   12
# 72+Rutledge+Crescent+Winnipeg+MB                              13
# 29+Des+Meurons+St+Winnipeg+MB                                  9
#
#                                     135+Driftwood+Bay+Winnipeg+MB  ...  \
# 1555+Regent+Ave+W+Winnipeg+MB                                  15  ...
# 272+Poplarwood+Ave+Winnipeg+MB                                  7  ...
# 378+Jacques+Ave+Winnipeg+MB                                    17  ...
# 532+Cherrier+St+Winnipeg+MB                                    12  ...
# 95+Fallbrook+Bay+Winnipeg+MB                                    5  ...
# 63+Regal+Ave+Winnipeg+MB                                       10  ...
# 1320+Concordia+Ave+E+Winnipeg+MB                               15  ...
# 11+Rizzuto+Bay+Winnipeg+MB                                     15  ...
# 876+Elizabeth+Rd+Winnipeg+MB                                    9  ...
# 135+Driftwood+Bay+Winnipeg+MB                                   0  ...
# 9+Kootenay+Crescent+Winnipeg+MB                                18  ...
# 1575+Lagimodiere+Blvd+Winnipeg+MB                              15  ...
# 47+Eric+St+Winnipeg+MB                                          9  ...
# 45+Willowlake+Crescent+Winnipeg+MB                              3  ...
# 515+St+Anne's+Rd+Winnipeg+MB                                    7  ...
# 209+Yale+Ave+W+Winnipeg+MB                                     18  ...
# 150+Howden+Rd+Winnipeg+MB                                       9  ...
# 75+Golis+Bay+Winnipeg+MB                                       18  ...
# 975+Cottonwood+Rd+Winnipeg+MB                                   7  ...
# 556+Brewster+St+Winnipeg+MB                                    17  ...
# 72+Rutledge+Crescent+Winnipeg+MB                               18  ...
# 29+Des+Meurons+St+Winnipeg+MB                                  13  ...
#
#                                     47+Eric+St+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                           20
# 272+Poplarwood+Ave+Winnipeg+MB                           5
# 378+Jacques+Ave+Winnipeg+MB                             22
# 532+Cherrier+St+Winnipeg+MB                             14
# 95+Fallbrook+Bay+Winnipeg+MB                             9
# 63+Regal+Ave+Winnipeg+MB                                 7
# 1320+Concordia+Ave+E+Winnipeg+MB                        20
# 11+Rizzuto+Bay+Winnipeg+MB                              20
# 876+Elizabeth+Rd+Winnipeg+MB                            12
# 135+Driftwood+Bay+Winnipeg+MB                            8
# 9+Kootenay+Crescent+Winnipeg+MB                         22
# 1575+Lagimodiere+Blvd+Winnipeg+MB                       19
# 47+Eric+St+Winnipeg+MB                                   0
# 45+Willowlake+Crescent+Winnipeg+MB                       8
# 515+St+Anne's+Rd+Winnipeg+MB                             4
# 209+Yale+Ave+W+Winnipeg+MB                              22
# 150+Howden+Rd+Winnipeg+MB                               12
# 75+Golis+Bay+Winnipeg+MB                                23
# 975+Cottonwood+Rd+Winnipeg+MB                           10
# 556+Brewster+St+Winnipeg+MB                             20
# 72+Rutledge+Crescent+Winnipeg+MB                        23
# 29+Des+Meurons+St+Winnipeg+MB                           10
#
#                                     45+Willowlake+Crescent+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                       15
# 272+Poplarwood+Ave+Winnipeg+MB                                       7
# 378+Jacques+Ave+Winnipeg+MB                                         17
# 532+Cherrier+St+Winnipeg+MB                                          9
# 95+Fallbrook+Bay+Winnipeg+MB                                         2
# 63+Regal+Ave+Winnipeg+MB                                             7
# 1320+Concordia+Ave+E+Winnipeg+MB                                    16
# 11+Rizzuto+Bay+Winnipeg+MB                                          15
# 876+Elizabeth+Rd+Winnipeg+MB                                         7
# 135+Driftwood+Bay+Winnipeg+MB                                        3
# 9+Kootenay+Crescent+Winnipeg+MB                                     18
# 1575+Lagimodiere+Blvd+Winnipeg+MB                                   15
# 47+Eric+St+Winnipeg+MB                                               9
# 45+Willowlake+Crescent+Winnipeg+MB                                   0
# 515+St+Anne's+Rd+Winnipeg+MB                                         7
# 209+Yale+Ave+W+Winnipeg+MB                                          18
# 150+Howden+Rd+Winnipeg+MB                                            7
# 75+Golis+Bay+Winnipeg+MB                                            18
# 975+Cottonwood+Rd+Winnipeg+MB                                        5
# 556+Brewster+St+Winnipeg+MB                                         17
# 72+Rutledge+Crescent+Winnipeg+MB                                    19
# 29+Des+Meurons+St+Winnipeg+MB                                       10
#
#                                     515+St+Anne's+Rd+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                 16
# 272+Poplarwood+Ave+Winnipeg+MB                                 3
# 378+Jacques+Ave+Winnipeg+MB                                   19
# 532+Cherrier+St+Winnipeg+MB                                   12
# 95+Fallbrook+Bay+Winnipeg+MB                                   6
# 63+Regal+Ave+Winnipeg+MB                                       7
# 1320+Concordia+Ave+E+Winnipeg+MB                              17
# 11+Rizzuto+Bay+Winnipeg+MB                                    17
# 876+Elizabeth+Rd+Winnipeg+MB                                  11
# 135+Driftwood+Bay+Winnipeg+MB                                  5
# 9+Kootenay+Crescent+Winnipeg+MB                               19
# 1575+Lagimodiere+Blvd+Winnipeg+MB                             16
# 47+Eric+St+Winnipeg+MB                                         5
# 45+Willowlake+Crescent+Winnipeg+MB                             5
# 515+St+Anne's+Rd+Winnipeg+MB                                   0
# 209+Yale+Ave+W+Winnipeg+MB                                    19
# 150+Howden+Rd+Winnipeg+MB                                     11
# 75+Golis+Bay+Winnipeg+MB                                      20
# 975+Cottonwood+Rd+Winnipeg+MB                                  9
# 556+Brewster+St+Winnipeg+MB                                   17
# 72+Rutledge+Crescent+Winnipeg+MB                              20
# 29+Des+Meurons+St+Winnipeg+MB                                 10
#
#                                     209+Yale+Ave+W+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                               10
# 272+Poplarwood+Ave+Winnipeg+MB                              19
# 378+Jacques+Ave+Winnipeg+MB                                 10
# 532+Cherrier+St+Winnipeg+MB                                 16
# 95+Fallbrook+Bay+Winnipeg+MB                                18
# 63+Regal+Ave+Winnipeg+MB                                    20
# 1320+Concordia+Ave+E+Winnipeg+MB                             9
# 11+Rizzuto+Bay+Winnipeg+MB                                   9
# 876+Elizabeth+Rd+Winnipeg+MB                                14
# 135+Driftwood+Bay+Winnipeg+MB                               17
# 9+Kootenay+Crescent+Winnipeg+MB                              5
# 1575+Lagimodiere+Blvd+Winnipeg+MB                           12
# 47+Eric+St+Winnipeg+MB                                      22
# 45+Willowlake+Crescent+Winnipeg+MB                          17
# 515+St+Anne's+Rd+Winnipeg+MB                                20
# 209+Yale+Ave+W+Winnipeg+MB                                   0
# 150+Howden+Rd+Winnipeg+MB                                   16
# 75+Golis+Bay+Winnipeg+MB                                    11
# 975+Cottonwood+Rd+Winnipeg+MB                               15
# 556+Brewster+St+Winnipeg+MB                                  4
# 72+Rutledge+Crescent+Winnipeg+MB                            11
# 29+Des+Meurons+St+Winnipeg+MB                               19
#
#                                     150+Howden+Rd+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                              10
# 272+Poplarwood+Ave+Winnipeg+MB                              9
# 378+Jacques+Ave+Winnipeg+MB                                13
# 532+Cherrier+St+Winnipeg+MB                                 8
# 95+Fallbrook+Bay+Winnipeg+MB                                8
# 63+Regal+Ave+Winnipeg+MB                                   10
# 1320+Concordia+Ave+E+Winnipeg+MB                           11
# 11+Rizzuto+Bay+Winnipeg+MB                                 11
# 876+Elizabeth+Rd+Winnipeg+MB                                3
# 135+Driftwood+Bay+Winnipeg+MB                              10
# 9+Kootenay+Crescent+Winnipeg+MB                            14
# 1575+Lagimodiere+Blvd+Winnipeg+MB                          10
# 47+Eric+St+Winnipeg+MB                                     13
# 45+Willowlake+Crescent+Winnipeg+MB                          8
# 515+St+Anne's+Rd+Winnipeg+MB                               10
# 209+Yale+Ave+W+Winnipeg+MB                                 14
# 150+Howden+Rd+Winnipeg+MB                                   0
# 75+Golis+Bay+Winnipeg+MB                                   14
# 975+Cottonwood+Rd+Winnipeg+MB                               4
# 556+Brewster+St+Winnipeg+MB                                13
# 72+Rutledge+Crescent+Winnipeg+MB                           14
# 29+Des+Meurons+St+Winnipeg+MB                              11
#
#                                     75+Golis+Bay+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                              7
# 272+Poplarwood+Ave+Winnipeg+MB                            20
# 378+Jacques+Ave+Winnipeg+MB                                4
# 532+Cherrier+St+Winnipeg+MB                               14
# 95+Fallbrook+Bay+Winnipeg+MB                              18
# 63+Regal+Ave+Winnipeg+MB                                  20
# 1320+Concordia+Ave+E+Winnipeg+MB                           3
# 11+Rizzuto+Bay+Winnipeg+MB                                 9
# 876+Elizabeth+Rd+Winnipeg+MB                              12
# 135+Driftwood+Bay+Winnipeg+MB                             18
# 9+Kootenay+Crescent+Winnipeg+MB                            8
# 1575+Lagimodiere+Blvd+Winnipeg+MB                          6
# 47+Eric+St+Winnipeg+MB                                    23
# 45+Willowlake+Crescent+Winnipeg+MB                        18
# 515+St+Anne's+Rd+Winnipeg+MB                              20
# 209+Yale+Ave+W+Winnipeg+MB                                11
# 150+Howden+Rd+Winnipeg+MB                                 14
# 75+Golis+Bay+Winnipeg+MB                                   0
# 975+Cottonwood+Rd+Winnipeg+MB                             14
# 556+Brewster+St+Winnipeg+MB                                8
# 72+Rutledge+Crescent+Winnipeg+MB                           4
# 29+Des+Meurons+St+Winnipeg+MB                             17
#
#                                     975+Cottonwood+Rd+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                  11
# 272+Poplarwood+Ave+Winnipeg+MB                                  6
# 378+Jacques+Ave+Winnipeg+MB                                    13
# 532+Cherrier+St+Winnipeg+MB                                     7
# 95+Fallbrook+Bay+Winnipeg+MB                                    5
# 63+Regal+Ave+Winnipeg+MB                                        7
# 1320+Concordia+Ave+E+Winnipeg+MB                               12
# 11+Rizzuto+Bay+Winnipeg+MB                                     11
# 876+Elizabeth+Rd+Winnipeg+MB                                    4
# 135+Driftwood+Bay+Winnipeg+MB                                   7
# 9+Kootenay+Crescent+Winnipeg+MB                                15
# 1575+Lagimodiere+Blvd+Winnipeg+MB                              11
# 47+Eric+St+Winnipeg+MB                                         10
# 45+Willowlake+Crescent+Winnipeg+MB                              5
# 515+St+Anne's+Rd+Winnipeg+MB                                    7
# 209+Yale+Ave+W+Winnipeg+MB                                     15
# 150+Howden+Rd+Winnipeg+MB                                       3
# 75+Golis+Bay+Winnipeg+MB                                       14
# 975+Cottonwood+Rd+Winnipeg+MB                                   0
# 556+Brewster+St+Winnipeg+MB                                    14
# 72+Rutledge+Crescent+Winnipeg+MB                               15
# 29+Des+Meurons+St+Winnipeg+MB                                  10
#
#                                     556+Brewster+St+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                 8
# 272+Poplarwood+Ave+Winnipeg+MB                               18
# 378+Jacques+Ave+Winnipeg+MB                                   7
# 532+Cherrier+St+Winnipeg+MB                                  14
# 95+Fallbrook+Bay+Winnipeg+MB                                 16
# 63+Regal+Ave+Winnipeg+MB                                     18
# 1320+Concordia+Ave+E+Winnipeg+MB                              7
# 11+Rizzuto+Bay+Winnipeg+MB                                    7
# 876+Elizabeth+Rd+Winnipeg+MB                                 13
# 135+Driftwood+Bay+Winnipeg+MB                                16
# 9+Kootenay+Crescent+Winnipeg+MB                               2
# 1575+Lagimodiere+Blvd+Winnipeg+MB                            10
# 47+Eric+St+Winnipeg+MB                                       20
# 45+Willowlake+Crescent+Winnipeg+MB                           16
# 515+St+Anne's+Rd+Winnipeg+MB                                 19
# 209+Yale+Ave+W+Winnipeg+MB                                    4
# 150+Howden+Rd+Winnipeg+MB                                    14
# 75+Golis+Bay+Winnipeg+MB                                      9
# 975+Cottonwood+Rd+Winnipeg+MB                                14
# 556+Brewster+St+Winnipeg+MB                                   0
# 72+Rutledge+Crescent+Winnipeg+MB                              9
# 29+Des+Meurons+St+Winnipeg+MB                                17
#
#                                     72+Rutledge+Crescent+Winnipeg+MB  \
# 1555+Regent+Ave+W+Winnipeg+MB                                      8
# 272+Poplarwood+Ave+Winnipeg+MB                                    20
# 378+Jacques+Ave+Winnipeg+MB                                        3
# 532+Cherrier+St+Winnipeg+MB                                       14
# 95+Fallbrook+Bay+Winnipeg+MB                                      19
# 63+Regal+Ave+Winnipeg+MB                                          20
# 1320+Concordia+Ave+E+Winnipeg+MB                                   4
# 11+Rizzuto+Bay+Winnipeg+MB                                        10
# 876+Elizabeth+Rd+Winnipeg+MB                                      13
# 135+Driftwood+Bay+Winnipeg+MB                                     18
# 9+Kootenay+Crescent+Winnipeg+MB                                    9
# 1575+Lagimodiere+Blvd+Winnipeg+MB                                  6
# 47+Eric+St+Winnipeg+MB                                            23
# 45+Willowlake+Crescent+Winnipeg+MB                                18
# 515+St+Anne's+Rd+Winnipeg+MB                                      21
# 209+Yale+Ave+W+Winnipeg+MB                                        11
# 150+Howden+Rd+Winnipeg+MB                                         14
# 75+Golis+Bay+Winnipeg+MB                                           4
# 975+Cottonwood+Rd+Winnipeg+MB                                     14
# 556+Brewster+St+Winnipeg+MB                                        8
# 72+Rutledge+Crescent+Winnipeg+MB                                   0
# 29+Des+Meurons+St+Winnipeg+MB                                     17
#
#                                     29+Des+Meurons+St+Winnipeg+MB
# 1555+Regent+Ave+W+Winnipeg+MB                                  15
# 272+Poplarwood+Ave+Winnipeg+MB                                  8
# 378+Jacques+Ave+Winnipeg+MB                                    17
# 532+Cherrier+St+Winnipeg+MB                                     7
# 95+Fallbrook+Bay+Winnipeg+MB                                   10
# 63+Regal+Ave+Winnipeg+MB                                        6
# 1320+Concordia+Ave+E+Winnipeg+MB                               15
# 11+Rizzuto+Bay+Winnipeg+MB                                     15
# 876+Elizabeth+Rd+Winnipeg+MB                                   10
# 135+Driftwood+Bay+Winnipeg+MB                                  13
# 9+Kootenay+Crescent+Winnipeg+MB                                19
# 1575+Lagimodiere+Blvd+Winnipeg+MB                              15
# 47+Eric+St+Winnipeg+MB                                         10
# 45+Willowlake+Crescent+Winnipeg+MB                             10
# 515+St+Anne's+Rd+Winnipeg+MB                                    8
# 209+Yale+Ave+W+Winnipeg+MB                                     19
# 150+Howden+Rd+Winnipeg+MB                                      11
# 75+Golis+Bay+Winnipeg+MB                                       18
# 975+Cottonwood+Rd+Winnipeg+MB                                   9
# 556+Brewster+St+Winnipeg+MB                                    17
# 72+Rutledge+Crescent+Winnipeg+MB                               18
# 29+Des+Meurons+St+Winnipeg+MB                                   0
#
# [22 rows x 22 columns]

# %%
#saves the data
#save_path = "C:/Users/ehniv/Desktop/MATH448-SaveOn/winnipeg_test_2/time_matrix.csv"
#processed_data.to_csv(save_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_484/174252967.py in <module>
#       1 #saves the data
#       2 save_path = "C:/Users/ehniv/Desktop/MATH448-SaveOn/winnipeg_test_2/time_matrix.csv"
# ----> 3 processed_data.to_csv(save_path)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3464         )
#    3465
# -> 3466         return DataFrameRenderer(formatter).to_csv(
#    3467             path_or_buf,
#    3468             line_terminator=line_terminator,
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1103             formatter=self.fmt,
#    1104         )
# -> 1105         csv_formatter.save()
#    1106
#    1107         if created_buffer:
#
# ~\anaconda3\lib\site-packages\pandas\io\formats\csvs.py in save(self)
#     235         """
#     236         # apply compression and byte/text conversion
# --> 237         with get_handle(
#     238             self.filepath_or_buffer,
#     239             self.mode,
#
# ~\anaconda3\lib\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     700         if ioargs.encoding and "b" not in ioargs.mode:
#     701             # Encoding
# --> 702             handle = open(
#     703                 handle,
#     704                 ioargs.mode,
#
# FileNotFoundError: [Errno 2] No such file or directory: 'C:/Users/ehniv/Desktop/MATH448-SaveOn/winnipeg_test_2/time_matrix.csv'

# %% [markdown]
# # Adds in delivery time

# %%
# adds in the time slots
slot_capacity = {'7AM-2PM':7,
                 '7AM-9AM':5,
                 '9AM-11AM':5,
                 '12PM-2PM':4}

time_slots = []
for slot in slot_capacity:
    for frequency in range(slot_capacity[slot]):
        time_slots.append(slot)

random.shuffle(time_slots)
time_slots = [data['delivery_start_time']+ '-' + data['delivery_end_time']] + time_slots

time_slot_data = pd.DataFrame(time_slots, columns = ['slots'])
time_slot_data.index = address_prepared
time_slot_data.head(n = 5)
# Out:
#                                    slots
# 1555+Regent+Ave+W+Winnipeg+MB    7AM-2PM
# 272+Poplarwood+Ave+Winnipeg+MB   7AM-9AM
# 378+Jacques+Ave+Winnipeg+MB     12PM-2PM
# 532+Cherrier+St+Winnipeg+MB      7AM-2PM
# 95+Fallbrook+Bay+Winnipeg+MB    9AM-11AM

# %%
time_slot_data['start_time'] = time_slot_data['slots'].str.split('-', expand = True)[0]
time_slot_data['end_time'] = time_slot_data['slots'].str.split('-', expand = True)[1]


time_slot_data['start_time'] = pd.to_datetime(time_slot_data['start_time'], format = '%I%p')
time_slot_data['end_time'] = pd.to_datetime(time_slot_data['end_time'], format = '%I%p')

# %%
time_slot_data.head(n = 5)
# Out:
#                                    slots          start_time  \
# 1555+Regent+Ave+W+Winnipeg+MB    7AM-2PM 1900-01-01 07:00:00
# 272+Poplarwood+Ave+Winnipeg+MB   7AM-9AM 1900-01-01 07:00:00
# 378+Jacques+Ave+Winnipeg+MB     12PM-2PM 1900-01-01 12:00:00
# 532+Cherrier+St+Winnipeg+MB      7AM-2PM 1900-01-01 07:00:00
# 95+Fallbrook+Bay+Winnipeg+MB    9AM-11AM 1900-01-01 09:00:00
#
#                                           end_time
# 1555+Regent+Ave+W+Winnipeg+MB  1900-01-01 14:00:00
# 272+Poplarwood+Ave+Winnipeg+MB 1900-01-01 09:00:00
# 378+Jacques+Ave+Winnipeg+MB    1900-01-01 14:00:00
# 532+Cherrier+St+Winnipeg+MB    1900-01-01 14:00:00
# 95+Fallbrook+Bay+Winnipeg+MB   1900-01-01 11:00:00

# %% [markdown]
# Calculates the amount of time in minutes we have from the start and end time of each delivery slot
# - used for ortools optimizer

# %%
# computes the difference start/end - delivery start time
delivery_start_time = datetime.datetime.strptime(data['delivery_start_time'], '%I%p')
time_slot_data['start_time_scaled'] = time_slot_data['start_time'] - delivery_start_time
time_slot_data['end_time_scaled'] = time_slot_data['end_time'] - delivery_start_time


#finds the difference in minutes
time_slot_data['start_time_scaled'] = time_slot_data["start_time_scaled"].dt.total_seconds()/60
time_slot_data['end_time_scaled'] = time_slot_data["end_time_scaled"].dt.total_seconds()/60

time_slot_data['start_time_scaled'] = time_slot_data['start_time_scaled'].astype('int')
time_slot_data['end_time_scaled'] = time_slot_data['end_time_scaled'].astype('int')

# %%
time_slot_data.head(n = 5)
# Out:
#                                    slots          start_time  \
# 1555+Regent+Ave+W+Winnipeg+MB    7AM-2PM 1900-01-01 07:00:00
# 272+Poplarwood+Ave+Winnipeg+MB   7AM-9AM 1900-01-01 07:00:00
# 378+Jacques+Ave+Winnipeg+MB     12PM-2PM 1900-01-01 12:00:00
# 532+Cherrier+St+Winnipeg+MB      7AM-2PM 1900-01-01 07:00:00
# 95+Fallbrook+Bay+Winnipeg+MB    9AM-11AM 1900-01-01 09:00:00
#
#                                           end_time  start_time_scaled  \
# 1555+Regent+Ave+W+Winnipeg+MB  1900-01-01 14:00:00                  0
# 272+Poplarwood+Ave+Winnipeg+MB 1900-01-01 09:00:00                  0
# 378+Jacques+Ave+Winnipeg+MB    1900-01-01 14:00:00                300
# 532+Cherrier+St+Winnipeg+MB    1900-01-01 14:00:00                  0
# 95+Fallbrook+Bay+Winnipeg+MB   1900-01-01 11:00:00                120
#
#                                 end_time_scaled
# 1555+Regent+Ave+W+Winnipeg+MB               420
# 272+Poplarwood+Ave+Winnipeg+MB              120
# 378+Jacques+Ave+Winnipeg+MB                 420
# 532+Cherrier+St+Winnipeg+MB                 420
# 95+Fallbrook+Bay+Winnipeg+MB                240

# %%
save_path = "C:/Users/ehniv/Desktop/MATH448-SaveOn/winnipeg_test_1/time_slot.csv"
time_slot_data.to_csv(save_path)
